# %%
# pip install sdv pandas numpy

# %%
# %pip install -U sdv
# Out:
# Collecting sdv
#   Downloading sdv-1.32.0-py3-none-any.whl.metadata (14 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.42.16-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.42.16-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (3.1.2)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.12/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting ctgan>=0.11.1 (from sdv)
#   Downloading ctgan-0.11.1-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.18.2 (from sdv)
#   Downloading rdt-1.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.24.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (4.5.1)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (6.0.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.5.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.12/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from copulas>=0.12.1->sdv) (1.16.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from ctgan>=0.11.1->sdv) (2.9.0+cpu)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdv) (2025.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.18.2->sdv) (1.6.1)
# Collecting Faker!=37.11.0,>=17 (from rdt>=1.18.2->sdv)
#   Downloading faker-39.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.3.0->ctgan>=0.11.1->sdv) (3.0.3)
# Downloading sdv-1.32.0-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.5/198.5 kB 14.9 MB/s eta 0:00:00
# Downloading boto3-1.42.16-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 14.1 MB/s eta 0:00:00
# Downloading botocore-1.42.16-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 114.1 MB/s eta 0:00:00
# Downloading copulas-0.12.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 5.3 MB/s eta 0:00:00
# Downloading ctgan-0.11.1-py3-none-any.whl (25 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.18.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 5.9 MB/s eta 0:00:00
# Downloading sdmetrics-0.24.0-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.3/198.3 kB 19.5 MB/s eta 0:00:00
# Downloading faker-39.0.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: jmespath, Faker, botocore, s3transfer, rdt, deepecho, copulas, sdmetrics, ctgan, boto3, sdv
# Successfully installed Faker-39.0.0 boto3-1.42.16 botocore-1.42.16 copulas-0.12.3 ctgan-0.11.1 deepecho-0.7.0 jmespath-1.0.1 rdt-1.18.2 s3transfer-0.16.0 sdmetrics-0.24.0 sdv-1.32.0

# %%
import sdv
print(sdv.__version__)
# Out:
# 1.32.0

# %%
import pandas as pd
import numpy as np

from sdv.metadata import MultiTableMetadata
from sdv.multi_table import HMASynthesizer

# %% [markdown]
# Store Master

# %%
NUM_SKUS = 50

SKU_LIST = [f"SKU_{i}" for i in range(1, NUM_SKUS + 1)]

CATEGORY_LIST = [
    "Bev",
    "Snack",
    "Dairy",
    "Personal Care",
    "Home Care",
    "Confectionery",
    "Health",
    "Frozen",
    "Bakery",
    "Grocery"
]

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

stores = pd.DataFrame({
    "Store_ID": [f"S{i:03d}" for i in range(1, 51)],
    "Store_Name": [f"Store_{i}" for i in range(1, 51)],
    "Region": np.random.choice(["North","South","East","West"], 50),
    "Segment": np.random.choice(["Gold","Silver","Bronze"], 50, p=[0.3, 0.4, 0.3]),
    "Revenue_L3M": np.random.uniform(4000, 15000, 50).round(0),
    "YoY_Growth_%": np.random.uniform(-5, 15, 50).round(2),
    "Market_Share_%": np.random.uniform(5, 25, 50).round(1),
    "Last_Visit_Days_Ago": np.random.randint(1, 60, 50),
    "Visit_Frequency_Target": np.random.choice(
        ["1 (per month)", "2 (per month)", "4 (per month)"], 50
    )
})

# 🔧 CHANGE: Segment ↔ Revenue sanity
stores.loc[stores.Segment == "Gold", "Revenue_L3M"] *= 1.2
stores.loc[stores.Segment == "Bronze", "Revenue_L3M"] *= 0.8
stores["Revenue_L3M"] = stores["Revenue_L3M"].round(0)

# %%
product_master = pd.DataFrame({
    "SKU_ID": SKU_LIST,

    # 🔧 CHANGE: auto-generated product names
    "Product_Name": [f"Product_{i}" for i in range(1, NUM_SKUS + 1)],

    # 🔧 CHANGE: 10 categories
    "Category": np.random.choice(CATEGORY_LIST, NUM_SKUS),

    # 🔧 CHANGE: realistic focus product ratio
    "Focus_Product?": np.random.choice(
        ["Yes", "No"],
        NUM_SKUS,
        p=[0.2, 0.8]
    ),

    "Active_Promo": np.random.choice(
        ["None", "10% Off", "Buy 5 Get 1", "Buy 2 Get 1"],
        NUM_SKUS,
        p=[0.6, 0.15, 0.15, 0.10]
    ),

    "Margin_Story": np.random.choice(
        [
            "High volume driver",
            "Impulse purchase",
            "Premium growth SKU",
            "Seasonal demand"
        ],
        NUM_SKUS
    )
})

# %%
pricing = pd.DataFrame({
    "SKU_ID": SKU_LIST,

    # 🔧 CHANGE: price in multiples of 10
    "List_Price": np.random.choice(
        np.arange(20, 201, 10),
        NUM_SKUS
    ),

    "COGS (Cost)": np.random.randint(10, 120, NUM_SKUS),

    "Min_Acceptable_Margin_%": np.random.choice(
        [15, 18, 20, 22, 25],
        NUM_SKUS
    ),

    "FSR_Max_Disc_%": np.random.choice([5, 6, 7, 8], NUM_SKUS),

    "Mgr_Approval_Disc_%": np.random.choice([10, 12, 15], NUM_SKUS)
})

# 🔧 CHANGE: enforce pricing sanity
pricing["COGS (Cost)"] = np.minimum(
    pricing["COGS (Cost)"],
    pricing["List_Price"] * 0.8
)

pricing["FSR_Max_Disc_%"] = np.minimum(
    pricing["FSR_Max_Disc_%"],
    pricing["Mgr_Approval_Disc_%"]
)

# %%
dates = pd.date_range("2023-07-01", "2024-06-30")
transactions = pd.DataFrame({
    "Store_ID": np.random.choice(stores.Store_ID, 12000),
    "SKU_ID": np.random.choice(SKU_LIST, 12000),
    "Last_Purchase_Date": np.random.choice(dates, 12000),
    "Avg_Order_Qty": np.random.poisson(30, 12000),
    "Last_Order_Qty": np.random.poisson(25, 12000)
})

# Category still derived from product_master (NO CHANGE)
transactions = transactions.merge(
    product_master[['SKU_ID', 'Category']],
    on='SKU_ID',
    how='left'
)

transactions["Avg_Order_Qty"] = np.maximum(
    transactions["Avg_Order_Qty"],
    transactions["Last_Order_Qty"]
)

# %%
inventory = pd.DataFrame({
    "Store_ID": np.random.choice(stores.Store_ID, 6000),
    "SKU_ID": np.random.choice(SKU_LIST, 6000),

    "Inventory_Date": np.random.choice(
        pd.date_range("2023-07-01", "2024-06-30", freq="W"),
        6000
    ),

    "Est_Current_Stock": np.random.randint(5, 60, 6000),
    "Reorder_Level": np.random.randint(10, 30, 6000)
})

inventory["Reorder_Level"] = np.minimum(
    inventory["Reorder_Level"],
    inventory["Est_Current_Stock"] - 1
).clip(lower=0)

# %%
# 🔧 CHANGE: Ensure sales happen BEFORE inventory snapshot
transactions = transactions.merge(
    inventory[['Store_ID','SKU_ID','Inventory_Date']],
    on=['Store_ID','SKU_ID'],
    how='left'
)

transactions = transactions[
    transactions["Last_Purchase_Date"] <= transactions["Inventory_Date"]
].drop(columns=["Inventory_Date"])

# %%
from sdv.metadata import MultiTableMetadata
from sdv.multi_table import HMASynthesizer

metadata = MultiTableMetadata()
metadata.detect_from_dataframes({
    "stores": stores,
    "product_master": product_master,
    "pricing": pricing,
    "transactions": transactions,
    "inventory": inventory
})
metadata.validate()

synthesizer = HMASynthesizer(metadata)

synthesizer.fit({
    "stores": stores,
    "product_master": product_master,
    "pricing": pricing,
    "transactions": transactions,
    "inventory": inventory
})
# Out:
# /usr/local/lib/python3.12/dist-packages/sdv/multi_table/base.py:120: FutureWarning: The 'MultiTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/sdv/multi_table/base.py:112: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sdv/single_table/base.py:168: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# Preprocess Tables: 100%|██████████| 5/5 [00:03<00:00,  1.56it/s]
# Learning relationships:
# (1/4) Tables 'stores' and 'transactions' ('Store_ID'): 100%|██████████| 50/50 [00:00<00:00, 62.29it/s]
# (2/4) Tables 'stores' and 'inventory' ('Store_ID'): 100%|██████████| 50/50 [00:00<00:00, 87.63it/s]
# (3/4) Tables 'product_master' and 'transactions' ('SKU_ID'): 100%|██████████| 50/50 [00:00<00:00, 99.48it/s]
# (4/4) Tables 'product_master' and 'inventory' ('SKU_ID'): 100%|██████████| 50/50 [00:00<00:00, 136.76it/s]
# Modeling Tables: 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]

# %%
from tqdm import tqdm

chunks = []

for _ in tqdm(range(3), desc="Generating synthetic data"):
    chunks.append(synthesizer.sample(scale=1))

synthetic = {
    table: pd.concat([c[table] for c in chunks], ignore_index=True)
    for table in chunks[0]
}
# Out:
# Generating synthetic data: 100%|██████████| 3/3 [00:56<00:00, 18.84s/it]

# %%
product_master[product_master['Active_Promo']=='None']['Focus_Product?'].value_counts()
# Out:
# Focus_Product?
# No     26
# Yes     2
# Name: count, dtype: int64

# %%
product_master
# Out:
#     SKU_ID Product_Name       Category Focus_Product? Active_Promo  \
# 0    SKU_1    Product_1        Grocery            Yes  Buy 5 Get 1
# 1    SKU_2    Product_2  Personal Care             No  Buy 2 Get 1
# 2    SKU_3    Product_3          Snack             No         None
# 3    SKU_4    Product_4  Personal Care             No  Buy 2 Get 1
# 4    SKU_5    Product_5        Grocery            Yes  Buy 5 Get 1
# 5    SKU_6    Product_6         Frozen            Yes  Buy 2 Get 1
# 6    SKU_7    Product_7         Frozen             No  Buy 5 Get 1
# 7    SKU_8    Product_8          Dairy             No         None
# 8    SKU_9    Product_9      Home Care             No      10% Off
# 9   SKU_10   Product_10  Confectionery             No         None
# 10  SKU_11   Product_11          Snack             No         None
# 11  SKU_12   Product_12          Snack             No         None
# 12  SKU_13   Product_13            Bev             No         None
# 13  SKU_14   Product_14         Frozen             No         None
# 14  SKU_15   Product_15  Personal Care            Yes      10% Off
# 15  SKU_16   Product_16          Snack             No         None
# 16  SKU_17   Product_17            Bev             No         None
# 17  SKU_18   Product_18          Dairy             No  Buy 5 Get 1
# 18  SKU_19   Product_19         Bakery             No         None
# 19  SKU_20   Product_20          Snack             No  Buy 2 Get 1
# 20  SKU_21   Product_21         Frozen             No         None
# 21  SKU_22   Product_22  Personal Care             No      10% Off
# 22  SKU_23   Product_23         Bakery             No         None
# 23  SKU_24   Product_24            Bev             No         None
# 24  SKU_25   Product_25         Frozen             No         None
# 25  SKU_26   Product_26        Grocery             No  Buy 5 Get 1
# 26  SKU_27   Product_27      Home Care             No  Buy 2 Get 1
# 27  SKU_28   Product_28         Frozen             No         None
# 28  SKU_29   Product_29  Personal Care             No         None
# 29  SKU_30   Product_30        Grocery             No  Buy 2 Get 1
# 30  SKU_31   Product_31         Health             No         None
# 31  SKU_32   Product_32         Bakery             No         None
# 32  SKU_33   Product_33         Frozen             No         None
# 33  SKU_34   Product_34            Bev             No         None
# 34  SKU_35   Product_35        Grocery             No         None
# 35  SKU_36   Product_36        Grocery             No      10% Off
# 36  SKU_37   Product_37            Bev            Yes         None
# 37  SKU_38   Product_38        Grocery             No         None
# 38  SKU_39   Product_39  Personal Care             No      10% Off
# 39  SKU_40   Product_40         Health             No  Buy 2 Get 1
# 40  SKU_41   Product_41      Home Care             No         None
# 41  SKU_42   Product_42         Bakery            Yes         None
# 42  SKU_43   Product_43        Grocery             No         None
# 43  SKU_44   Product_44        Grocery             No      10% Off
# 44  SKU_45   Product_45  Personal Care             No         None
# 45  SKU_46   Product_46         Bakery            Yes      10% Off
# 46  SKU_47   Product_47        Grocery             No  Buy 2 Get 1
# 47  SKU_48   Product_48  Personal Care             No  Buy 2 Get 1
# 48  SKU_49   Product_49  Personal Care             No         None
# 49  SKU_50   Product_50         Bakery             No  Buy 2 Get 1
#
#           Margin_Story
# 0   High volume driver
# 1   High volume driver
# 2     Impulse purchase
# 3   High volume driver
# 4   High volume driver
# 5     Impulse purchase
# 6     Impulse purchase
# 7      Seasonal demand
# 8   Premium growth SKU
# 9   Premium growth SKU
# 10  High volume driver
# 11  High volume driver
# 12  High volume driver
# 13  High volume driver
# 14  Premium growth SKU
# 15     Seasonal demand
# 16    Impulse purchase
# 17  High volume driver
# 18    Impulse purchase
# 19  High volume driver
# 20     Seasonal demand
# 21    Impulse purchase
# 22  High volume driver
# 23  High volume driver
# 24    Impulse purchase
# 25  Premium growth SKU
# 26    Impulse purchase
# 27     Seasonal demand
# 28  High volume driver
# 29    Impulse purchase
# 30  High volume driver
# 31    Impulse purchase
# 32    Impulse purchase
# 33     Seasonal demand
# 34     Seasonal demand
# 35  High volume driver
# 36    Impulse purchase
# 37    Impulse purchase
# 38  Premium growth SKU
# 39     Seasonal demand
# 40    Impulse purchase
# 41  Premium growth SKU
# 42     Seasonal demand
# 43  Premium growth SKU
# 44    Impulse purchase
# 45  High volume driver
# 46  Premium growth SKU
# 47     Seasonal demand
# 48  High volume driver
# 49    Impulse purchase

# %%
stores.to_csv("stores.csv",index=False)
stores.to_csv("stores.csv",index=False)

# %%
print("STORE MASTER")
display(stores.head())

print("PRODUCT MASTER")
display(product_master.head())

print("PRICING")
display(pricing.head())

print("TRANSACTIONS")
display(transactions.head())

print("INVENTORY")
display(inventory.head())
# Out:
# STORE MASTER
#   Store_ID Store_Name Region Segment  Revenue_L3M  YoY_Growth_%  \
# 0     S001    Store_1   East  Bronze       9615.0          3.54
# 1     S002    Store_2   West    Gold      14981.0         11.36
# 2     S003    Store_3  North  Silver       4814.0         12.21
# 3     S004    Store_4   East  Silver       7943.0         -4.86
# 4     S005    Store_5   East    Gold       6330.0          5.21
#
#    Market_Share_%  Last_Visit_Days_Ago Visit_Frequency_Target
# 0             8.5                   46          2 (per month)
# 1            18.8                   30          4 (per month)
# 2            12.7                   38          2 (per month)
# 3            23.7                   38          2 (per month)
# 4             7.8                   45          4 (per month)
# PRODUCT MASTER
#   SKU_ID Product_Name       Category Focus_Product? Active_Promo  \
# 0  SKU_1    Product_1        Grocery            Yes  Buy 5 Get 1
# 1  SKU_2    Product_2  Personal Care             No  Buy 2 Get 1
# 2  SKU_3    Product_3          Snack             No         None
# 3  SKU_4    Product_4  Personal Care             No  Buy 2 Get 1
# 4  SKU_5    Product_5        Grocery            Yes  Buy 5 Get 1
#
#          Margin_Story
# 0  High volume driver
# 1  High volume driver
# 2    Impulse purchase
# 3  High volume driver
# 4  High volume driver
# PRICING
#   SKU_ID  List_Price  COGS (Cost)  Min_Acceptable_Margin_%  FSR_Max_Disc_%  \
# 0  SKU_1          50         40.0                       18               5
# 1  SKU_2         110         88.0                       25               7
# 2  SKU_3          40         32.0                       22               5
# 3  SKU_4          20         16.0                       20               5
# 4  SKU_5         130        104.0                       22               6
#
#    Mgr_Approval_Disc_%
# 0                   15
# 1                   12
# 2                   10
# 3                   15
# 4                   15
# TRANSACTIONS
#   Store_ID  SKU_ID Last_Purchase_Date  Avg_Order_Qty  Last_Order_Qty  \
# 2     S022   SKU_3         2024-03-03             28              24
# 4     S022  SKU_43         2023-07-04             36              36
# 5     S022  SKU_43         2023-07-04             36              36
# 6     S022  SKU_43         2023-07-04             36              36
# 8     S042  SKU_49         2024-06-13             32              24
#
#         Category
# 2          Snack
# 4        Grocery
# 5        Grocery
# 6        Grocery
# 8  Personal Care
# INVENTORY
#   Store_ID  SKU_ID Inventory_Date  Est_Current_Stock  Reorder_Level
# 0     S035  SKU_10     2023-12-31                 41             11
# 1     S003   SKU_6     2024-03-03                 15             14
# 2     S030  SKU_13     2024-05-26                 29             24
# 3     S048   SKU_6     2024-05-26                 30             16
# 4     S025  SKU_36     2023-08-27                 14             13

# %%
transactions
# Out:
#       Store_ID  SKU_ID Last_Purchase_Date  Avg_Order_Qty  Last_Order_Qty  \
# 2         S022   SKU_3         2024-03-03             28              24
# 4         S022  SKU_43         2023-07-04             36              36
# 5         S022  SKU_43         2023-07-04             36              36
# 6         S022  SKU_43         2023-07-04             36              36
# 8         S042  SKU_49         2024-06-13             32              24
# ...        ...     ...                ...            ...             ...
# 30039     S026  SKU_43         2023-09-16             27              16
# 30040     S026  SKU_43         2023-09-16             27              16
# 30041     S026  SKU_43         2023-09-16             27              16
# 30044     S030   SKU_9         2023-11-18             25              24
# 30045     S030   SKU_5         2023-07-27             25              21
#
#             Category
# 2              Snack
# 4            Grocery
# 5            Grocery
# 6            Grocery
# 8      Personal Care
# ...              ...
# 30039        Grocery
# 30040        Grocery
# 30041        Grocery
# 30044      Home Care
# 30045        Grocery
#
# [14549 rows x 6 columns]

# %%
product_master
# Out:
#     SKU_ID Product_Name       Category Focus_Product? Active_Promo  \
# 0    SKU_1    Product_1        Grocery            Yes  Buy 5 Get 1
# 1    SKU_2    Product_2  Personal Care             No  Buy 2 Get 1
# 2    SKU_3    Product_3          Snack             No         None
# 3    SKU_4    Product_4  Personal Care             No  Buy 2 Get 1
# 4    SKU_5    Product_5        Grocery            Yes  Buy 5 Get 1
# 5    SKU_6    Product_6         Frozen            Yes  Buy 2 Get 1
# 6    SKU_7    Product_7         Frozen             No  Buy 5 Get 1
# 7    SKU_8    Product_8          Dairy             No         None
# 8    SKU_9    Product_9      Home Care             No      10% Off
# 9   SKU_10   Product_10  Confectionery             No         None
# 10  SKU_11   Product_11          Snack             No         None
# 11  SKU_12   Product_12          Snack             No         None
# 12  SKU_13   Product_13            Bev             No         None
# 13  SKU_14   Product_14         Frozen             No         None
# 14  SKU_15   Product_15  Personal Care            Yes      10% Off
# 15  SKU_16   Product_16          Snack             No         None
# 16  SKU_17   Product_17            Bev             No         None
# 17  SKU_18   Product_18          Dairy             No  Buy 5 Get 1
# 18  SKU_19   Product_19         Bakery             No         None
# 19  SKU_20   Product_20          Snack             No  Buy 2 Get 1
# 20  SKU_21   Product_21         Frozen             No         None
# 21  SKU_22   Product_22  Personal Care             No      10% Off
# 22  SKU_23   Product_23         Bakery             No         None
# 23  SKU_24   Product_24            Bev             No         None
# 24  SKU_25   Product_25         Frozen             No         None
# 25  SKU_26   Product_26        Grocery             No  Buy 5 Get 1
# 26  SKU_27   Product_27      Home Care             No  Buy 2 Get 1
# 27  SKU_28   Product_28         Frozen             No         None
# 28  SKU_29   Product_29  Personal Care             No         None
# 29  SKU_30   Product_30        Grocery             No  Buy 2 Get 1
# 30  SKU_31   Product_31         Health             No         None
# 31  SKU_32   Product_32         Bakery             No         None
# 32  SKU_33   Product_33         Frozen             No         None
# 33  SKU_34   Product_34            Bev             No         None
# 34  SKU_35   Product_35        Grocery             No         None
# 35  SKU_36   Product_36        Grocery             No      10% Off
# 36  SKU_37   Product_37            Bev            Yes         None
# 37  SKU_38   Product_38        Grocery             No         None
# 38  SKU_39   Product_39  Personal Care             No      10% Off
# 39  SKU_40   Product_40         Health             No  Buy 2 Get 1
# 40  SKU_41   Product_41      Home Care             No         None
# 41  SKU_42   Product_42         Bakery            Yes         None
# 42  SKU_43   Product_43        Grocery             No         None
# 43  SKU_44   Product_44        Grocery             No      10% Off
# 44  SKU_45   Product_45  Personal Care             No         None
# 45  SKU_46   Product_46         Bakery            Yes      10% Off
# 46  SKU_47   Product_47        Grocery             No  Buy 2 Get 1
# 47  SKU_48   Product_48  Personal Care             No  Buy 2 Get 1
# 48  SKU_49   Product_49  Personal Care             No         None
# 49  SKU_50   Product_50         Bakery             No  Buy 2 Get 1
#
#           Margin_Story
# 0   High volume driver
# 1   High volume driver
# 2     Impulse purchase
# 3   High volume driver
# 4   High volume driver
# 5     Impulse purchase
# 6     Impulse purchase
# 7      Seasonal demand
# 8   Premium growth SKU
# 9   Premium growth SKU
# 10  High volume driver
# 11  High volume driver
# 12  High volume driver
# 13  High volume driver
# 14  Premium growth SKU
# 15     Seasonal demand
# 16    Impulse purchase
# 17  High volume driver
# 18    Impulse purchase
# 19  High volume driver
# 20     Seasonal demand
# 21    Impulse purchase
# 22  High volume driver
# 23  High volume driver
# 24    Impulse purchase
# 25  Premium growth SKU
# 26    Impulse purchase
# 27     Seasonal demand
# 28  High volume driver
# 29    Impulse purchase
# 30  High volume driver
# 31    Impulse purchase
# 32    Impulse purchase
# 33     Seasonal demand
# 34     Seasonal demand
# 35  High volume driver
# 36    Impulse purchase
# 37    Impulse purchase
# 38  Premium growth SKU
# 39     Seasonal demand
# 40    Impulse purchase
# 41  Premium growth SKU
# 42     Seasonal demand
# 43  Premium growth SKU
# 44    Impulse purchase
# 45  High volume driver
# 46  Premium growth SKU
# 47     Seasonal demand
# 48  High volume driver
# 49    Impulse purchase

# %%
transactions.drop_duplicates()
# Out:
#       Store_ID  SKU_ID Last_Purchase_Date  Avg_Order_Qty  Last_Order_Qty  \
# 2         S022   SKU_3         2024-03-03             28              24
# 4         S022  SKU_43         2023-07-04             36              36
# 8         S042  SKU_49         2024-06-13             32              24
# 17        S043  SKU_42         2023-12-20             32              32
# 20        S037  SKU_13         2024-01-09             29              21
# ...        ...     ...                ...            ...             ...
# 30034     S026  SKU_39         2024-03-01             33              33
# 30037     S019  SKU_47         2024-01-11             34              26
# 30039     S026  SKU_43         2023-09-16             27              16
# 30044     S030   SKU_9         2023-11-18             25              24
# 30045     S030   SKU_5         2023-07-27             25              21
#
#             Category
# 2              Snack
# 4            Grocery
# 8      Personal Care
# 17            Bakery
# 20               Bev
# ...              ...
# 30034  Personal Care
# 30037        Grocery
# 30039        Grocery
# 30044      Home Care
# 30045        Grocery
#
# [7504 rows x 6 columns]

# %%
inventory[(inventory['Store_ID']=='S023') & (inventory['SKU_ID']=='SKU_D')].sort_values(by=['Inventory_Date'],ascending=True)
# Out:
#      Store_ID SKU_ID Inventory_Date  Est_Current_Stock  Reorder_Level
# 3820     S023  SKU_D     2023-07-02                 49             19
# 2734     S023  SKU_D     2023-07-02                  6              5
# 1176     S023  SKU_D     2023-07-30                 39             20
# 1472     S023  SKU_D     2023-08-27                 20             11
# 1055     S023  SKU_D     2023-09-03                 57             17
# 4779     S023  SKU_D     2023-09-03                 22             21
# 2501     S023  SKU_D     2023-09-03                 16             15
# 3917     S023  SKU_D     2023-09-17                 46             26
# 4597     S023  SKU_D     2023-09-24                 29             22
# 4709     S023  SKU_D     2023-10-01                  5              4
# 2812     S023  SKU_D     2023-10-08                 56             22
# 843      S023  SKU_D     2023-10-08                 43             24
# 1750     S023  SKU_D     2023-10-29                 20             19
# 3830     S023  SKU_D     2023-11-12                 38             15
# 3754     S023  SKU_D     2023-12-03                 19             17
# 2028     S023  SKU_D     2024-01-14                 41             28
# 3534     S023  SKU_D     2024-01-28                 57             13
# 3294     S023  SKU_D     2024-02-25                 16             15
# 2751     S023  SKU_D     2024-02-25                 10              9
# 3280     S023  SKU_D     2024-03-17                 18             17
# 1571     S023  SKU_D     2024-04-07                  6              5
# 1908     S023  SKU_D     2024-05-12                 10              9
# 2898     S023  SKU_D     2024-05-12                 20             19
# 5819     S023  SKU_D     2024-05-26                 51             26
# 5366     S023  SKU_D     2024-06-02                 41             17
# 110      S023  SKU_D     2024-06-30                  5              4
